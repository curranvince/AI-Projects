# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1440]*25, color='red', label='Without Solar')
plt.plot([719]*25, color='blue', label='Scenario 1')
plt.plot([1150]*25, color='orange', label='Scenario 2')
plt.plot([3982] + [382]*24, color='green', label='Scenario 3')
plt.title("Total Energy Costs")
plt.ylabel("Dollars")
plt.xlabel("Years")
plt.legend()
plt.show()
